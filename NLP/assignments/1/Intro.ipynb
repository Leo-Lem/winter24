# %%
# %%html
# <style>
# table {display: block;}
# td {
#   font-size: 20px
# }
# .rendered_html { font-size: 20px; }
# *{ line-height: 200%; }
# </style>
# Out:
# <style>
# table {display: block;}
# td {
#   font-size: 20px
# }
# .rendered_html { font-size: 20px; }
# *{ line-height: 200%; }
# </style>

# %% [markdown]
# # Welcome to the <span style="color:blue">Natural Language Processing and the Web WS24/25</span> course
# ###  Dr. Seid Muhie Yimam
#    * Email: seid.muhi.yimam@uni-hamburg.de
#    * Office: Informatikum, F-426
#    * Tel: 040 / 42883 - 2383
#
# ###  Saba Anwar
#    * Email saba.anwar@uni-hamburg.de
#    * Office: Informatikum, F-415
#    * Tel: 040 / 42883 - 2418

# %% [markdown]
# ## Practice Class
# ### When:
#    * Group-A: Wednesday 14:15 -- 15:45 => **F-534**
#    * Group-B: Wednesday 16:15 -- 17:45 => **D-125/129**
#    * Group-C: Friday 12:15 -- 13:45 => **G-102**
#
# ### Who:
#    1. Dr. Seid Muhie Yimam
#    2. Saba Anwar

# %% [markdown]
# ## Practice Class Policy
#
# > There will be <span style="color:red">3</span> components, you need to obtain at least <span style="color:red">50%</span> points in all of them, to appear in the final exam:
# > * **Weekly exercises** (<span style="color:red">0-1</span>) with a deadline of one week -- will be graded as <span style="color:red">0</span> or <span style="color:red">1</span> -- can be done in groups of 2-3
# >  * **ML project** (<span style="color:red">0-1</span>) with separate deadlines -- must be done in groups of 2-5
# >  * **Final project** (<span style="color:red">0-1</span>) with separate deadlines -- must be done in groups of 2-5
# ---
#
# * All exercises will use Python as a programming language with different NLP libraries(example <span style="color:blue">NLTK, spaCy</span>), visualization (example <span style="color:blue">mtplotlib</span> or <span style="color:blue">seaborn</span>) , and machine learning (example <span style="color:blue">scikit learn, fast.ai</span> and <span style="color:blue">PyTorch</span>) frameworks
#
# * You must use your own computer to do the exercises and projects

# %% [markdown]
# ## Tentative Outline
#
# | Week       | Topic  | Lecturer | When
# | ------------- |:-----| :-----| :-----|
# | 1 - 3 | NLTK and different NLP processing components |Seid/Saba  | Oct 16/18 -- Oct 30
# | 4 |  Introductions to ML using Scikit learn and Feature engineering| Seid/Saba  | Nov 6/8, (Distribute ML-project) |
# | 5 | Deep learning using PyTorch |Seid/Saba | Nov 13/15|
# | 6-8 | Large Language Models | Seid/Saba | Nov 12/14 - Dec 4/6|
# | 9 | ML Pproject presentation/Distribute Final Project idea  | Seid/Saba | Dec 11/13|
# | 10 | Final project proposal presentation/discussion | Seid/Saba | Dec 18/20  |
# | 11 - 13 | Final project development consultation | Seid/Saba | Dec 18/22 - Jan 22/24 |
# | 14 | Final project presentations | Seid/Saba | Jan 29/31 |

# %% [markdown]
# # Environment setup
# The Practice class will be conducted using <span style="color:blue">Python 3</span>. We will be using Jupyter notebooks for the most part, You can setup your machine with a local environment using Aanaconda, or use web-based solutions with python and notebook already installed, this could be Jupyter-hub (https://code.min.uni-hamburg.de/) from UHH (only CPU available) or Google Colab.

# %% [markdown]
# ## 1. How to install Python using Anaconda
#
# We will rely on <span style="color:blue">Anaconda3</span> (https://www.anaconda.com/distribution/), specifically version <span style="color:blue">3.7+</span>, a <span style="color:blue">Python</span> (and <span style="color:blue">R</span>) distribution which include most of the NLP and machine learning components. It also includes <span style="color:blue">Anaconda Navigator</span>, which is desktop graphical user interface that allows to launch different applications (Jupyter notebook, Spider GUI, GraphViz...) easily.
#
# Choose Python 3.7+ and install it to a location you prefer. Currently, Anconda installs around <span style="color:blue">200 packages</span>, which include <span style="color:blue">NLTK</span> and the <span style="color:blue">scikit learn</span> machine learning packages. See [here](http://docs.anaconda.com/anaconda) for the list of included packages.

# %% [markdown]
# ### Accessing Jupyter Notebook
# For most of the practice classes, we will use the <span style="color:blue">Jupyter Notebook</span> web application to run and demonstrate examples. Except in the case of developing complex assignments and projects, you will also use <span style="color:blue">Jupyter notebook</span> to submit your assignments and in-class exercises.
#
# ### How to open Jupyter Notebook:
# ####  Using Anaconda Navigation
#
# To open <span style="color:blue">Jupyter Notebook</span> using Anaconda navigator:
#
# Once Anaconda is installed, open <span style="color:blue">Anaconda Navigator</span> from your program/application lists for <span style="color:blue">MacOS</span> and <span style="color:blue">Windows</span>.
#
# For Linux, open a terminal and type `anaconda-navigator`
#
# Then you can choose either <span style="color:blue">JupyterLab</span> or <span style="color:blue">Jupyter Notebook</span> to open Jupyter notebook. You can also open it via Spyder but you need to install a notebook plugin
#
# ![jup.png](attachment:jup.png)
# ####  Open Juypter using command line
# From the command line, type:
# > `jupyter notebook`
#
# This will open the Jupyter Notebook in the browser.

# %% [markdown]
# ## 2. Google Colab
# Google provides a free cloud service based on Jupyter Notebooks that support free GPU, allows developing deep learning applications using PyTorch, TensorFlow, Keras, and so on.
# Using Colab, you can share your Jupyter notebooks, mount your Google Drive, etc.
#
# ### Creating a folder for your notebooks
# Go to Colab: https://colab.research.google.com/ and create a new notebook or open an existing notebook from your Google Drive.
# ![image.png](attachment:bc823db9-d261-443b-9f0f-b4c3d414bffd.png)
# Once the notebook is opened, you can set up your environment by selecting a GPU and installing the required libraries.
#
# ### Mounting your Google Drive
# Mounting your Google Drive allows you to persist models, files, and logs on your Google Drive folder as the Colab session is limited.
#
# Once in Colab, you can run the following code to mount to your Google Drive
# ```
# from google.colab import drive
# drive.mount('/content/drive')
#
# ```
# Follow the instructions and grant appropriate access in the subsequent windows. Your drive will be mounted as **drive**. To see the contents in your Google Drive
#
# > ```!ls "/content/drive/MyDrive/" ```

# %% [markdown]
# ## 3. Using UHH JupyterHub
# UHH also provides a web-based development environment that works for multiple languages e.g.  Python, Java, C, R among many others. You can access it here: (https://code.min.uni-hamburg.de/)using your stine credentials.

# %% [markdown]
# ## Notebook cheatsheet
# See [here](https://www.cheatography.com/weidadeyue/cheat-sheets/jupyter-notebook/pdf_bw/) to get the basic shortcuts and commands to execute a Jupyter notebook cell or display information
#
# Example: Inside a <span style="color:blue">cell</span>, The following are important shortcuts:
#
# 1.   `shift-Tab-Tab` -- Show documentation of methods or classes
# 1.   `shift-Enter` --- Execute cell and move/create the next cell
# 1.   `Ctrl-Enter` -- Execute a cell and remain the focus on the same cell
